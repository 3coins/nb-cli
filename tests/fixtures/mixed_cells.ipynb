# %% [markdown]
# # Analysis Notebook

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Loading

# %%
df = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})

# %% [raw]
# Raw cell content
