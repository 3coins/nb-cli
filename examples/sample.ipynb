# %% [markdown]
# # Data Analysis Example
#
# This notebook demonstrates basic data analysis operations.

# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# File ~/miniforge3/lib/python3.13/site-packages/pandas/__init__.py:19
#      16         _missing_dependencies.append(f"{_dependency}: {_e}")
#      18 if _missing_dependencies:  # pragma: no cover
# ---> 19     raise ImportError(
#      20         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      21     )
#      22 del _hard_dependencies, _dependency, _missing_dependencies
#      24 try:
#      25     # numpy compat
#
# ImportError: Unable to import required dependencies:
# numpy:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python 3.13 from "/Users/pijain/miniforge3/bin/python3"
#   * The NumPy version is: "2.4.2"
#
# and make sure that they are the versions you expect.
#
# Please carefully study the information and documentation linked above.
# This is unlikely to be a NumPy issue but will be caused by a bad install
# or environment on your machine.
#
# Original error was: dlopen(/Users/pijain/miniforge3/lib/python3.13/site-packages/numpy/_core/_multiarray_umath.cpython-313-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/pijain/miniforge3/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/pijain/miniforge3/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/pijain/miniforge3/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/pijain/miniforge3/lib/python3.13/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/pijain/miniforge3/lib/python3.13/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/pijain/miniforge3/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/pijain/miniforge3/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# File ~/miniforge3/lib/python3.13/site-packages/pandas/__init__.py:19
#      16         _missing_dependencies.append(f"{_dependency}: {_e}")
#      18 if _missing_dependencies:  # pragma: no cover
# ---> 19     raise ImportError(
#      20         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      21     )
#      22 del _hard_dependencies, _dependency, _missing_dependencies
#      24 try:
#      25     # numpy compat
#
# ImportError: Unable to import required dependencies:
# numpy:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python 3.13 from "/Users/pijain/miniforge3/bin/python3"
#   * The NumPy version is: "2.4.2"
#
# and make sure that they are the versions you expect.
#
# Please carefully study the information and documentation linked above.
# This is unlikely to be a NumPy issue but will be caused by a bad install
# or environment on your machine.
#
# Original error was: dlopen(/Users/pijain/miniforge3/lib/python3.13/site-packages/numpy/_core/_multiarray_umath.cpython-313-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/pijain/miniforge3/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/pijain/miniforge3/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/pijain/miniforge3/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/pijain/miniforge3/lib/python3.13/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/pijain/miniforge3/lib/python3.13/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/pijain/miniforge3/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/pijain/miniforge3/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)

# %% [markdown]
# ## Creating Sample Data

# %%
df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [4, 5, 6],
    'c': [7, 8, 9]
})
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
print("Mean values:")
print(df.mean())
# Out:
# Mean values:
# a    2.0
# b    5.0
# c    8.0
# dtype: float64

# %% [markdown]
# ## Conclusion
#
# The analysis shows consistent patterns across all columns.

# %%
# This cell hasn't been executed yet
result = df.sum()
